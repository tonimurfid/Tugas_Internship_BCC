# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/tonimurfid/Tugas_Internship_BCC/main/Data/Superstore.csv', encoding = "unicode_escape")
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 5       6  CA-2011-115812  09-06-2011  14-06-2011  Standard Class    BH-11710
# 6       7  CA-2011-115812  09-06-2011  14-06-2011  Standard Class    BH-11710
# 7       8  CA-2011-115812  09-06-2011  14-06-2011  Standard Class    BH-11710
# 8       9  CA-2011-115812  09-06-2011  14-06-2011  Standard Class    BH-11710
# 9      10  CA-2011-115812  09-06-2011  14-06-2011  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
# 5       90032    West  FUR-FU-10001487        Furniture  Furnishings
# 6       90032    West  OFF-AR-10002833  Office Supplies          Art
# 7       90032    West  TEC-PH-10002275       Technology       Phones
# 8       90032    West  OFF-BI-10003910  Office Supplies      Binders
# 9       90032    West  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
# 6                                         Newell 322    7.2800         4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520         6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040         3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000         5
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700
#
# [10 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
df['City'].value_counts()
# Out:
# City
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: count, Length: 531, dtype: int64

# %% [markdown]
# ## Soal

# %% [markdown]
# ### 1. Sub-kategori apa yang menghasilkan profit yang paling banyak ?

# %%
df_edit = df.groupby('Sub-Category').agg({'Profit':'sum'}).sort_values(by='Profit', ascending=False)
df_edit = pd.DataFrame(df_edit)

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df_edit, x='Sub-Category', y = 'Profit', palette='Set1')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.title('Most Profit')
# Out:
# C:\Users\Fatoni Murfid S\AppData\Local\Temp\ipykernel_11692\3255155069.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_edit, x='Sub-Category', y = 'Profit', palette='Set1')
# Text(0.5, 1.0, 'Most Profit')

# %% [markdown]
# #### Saran :
# Dengan data yang sudah diberikan, dapat diambil kesimpulan bahwa total profit terbanyak ada pada Sub-kategori Copiers, sehingga perusahaan dapat melakukan penyesuaian ulang mengenai strategi pemasaran agar dapat meningkatkan profit perusahaan kedepannya dan mengkaji ulang Sub-Kategori yang dijual, karena data yang ditampilkan menunjukkan beberapa sub-kategori mengalami loss

# %% [markdown]
# ### 2. Apa diskon berpengaruh pada profit yang didapat?

# %%
df_tes = df.copy()
df_tes['Discount'] = np.where(df_tes['Discount'] > 0, "Yes", "No")
# df_tes = df_tes.groupby('Discount').agg({'Profit':'sum'})

df_tes.to_csv('Discount2.csv')
df_tes
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156  09-11-2013  12-11-2013    Second Class
# 1          2  CA-2013-152156  09-11-2013  12-11-2013    Second Class
# 2          3  CA-2013-138688  13-06-2013  17-06-2013    Second Class
# 3          4  US-2012-108966  11-10-2012  18-10-2012  Standard Class
# 4          5  US-2012-108966  11-10-2012  18-10-2012  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2011-110422  22-01-2011  24-01-2011    Second Class
# 9990    9991  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9991    9992  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9992    9993  CA-2014-121258  27-02-2014  04-03-2014  Standard Class
# 9993    9994  CA-2014-119914  05-05-2014  10-05-2014    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0           No   41.9136
# 1           No  219.5820
# 2           No    6.8714
# 3          Yes -383.0310
# 4          Yes    2.5164
# ...        ...       ...
# 9989       Yes    4.1028
# 9990        No   15.6332
# 9991       Yes   19.3932
# 9992        No   13.3200
# 9993        No   72.9480
#
# [9994 rows x 21 columns]

# %%
sns.barplot(data=df_tes, x='Discount', y = 'Profit', palette='Set1')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.title('Most Profit')
# Out:
# C:\Users\Fatoni Murfid S\AppData\Local\Temp\ipykernel_11692\2378576716.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_tes, x='Discount', y = 'Profit', palette='Set1')
# Text(0.5, 1.0, 'Most Profit')

# %% [markdown]
# #### Saran :
# Dari data diatas dapat dilihat bahwa diskon dapat mempengaruhi profit yang dihasilkan, sehingga perlu dikaji ulang pengadaan diskon tersebut

# %% [markdown]
# ### 3. Apakah ada hubungan antara jumlah transaksi per Region dengan profit ?

# %%
region = df.groupby('Region').agg({'Profit':'sum'})
region = region.sort_values(by='Profit', ascending=True)
region
# Out:
#               Profit
# Region
# Central   39706.3625
# South     46749.4303
# East      91522.7800
# West     108418.4489

# %%
plt.pie(df['Region'].value_counts(), labels=df['Region'].unique(), autopct='%1.1f%%')
plt.title('Pie Chart Konsumen per Region')
plt.show()

# %%
region.plot(kind='barh', figsize=(10, 6))
plt.title('Total Profit by Region')
plt.xlabel('Profit')
plt.ylabel('Region')
plt.grid(axis='x')
plt.show()

# %% [markdown]
# #### Saran :
# Dari visualisasi diatas, bisa dilihat bahwa Region West merupakan penyumbang profit paling tinggi dan posisi kedua dalam jumlah transaksi terbanyak, sedangkan Region south berada di urutan pertama dalam jumlah transaksi per region, namun posisi ke 3 dalam total profit. Maka dari itu, dapat dilihat bahwa tidak selalu jumlah transaksi terbanyak akan menghasilkan profit terbanyak juga, hal tersebut dapat dipengaruhi oleh tren barang barang yang dibeli oleh masing masing region. Perlunya pengaturan strategi marketing untuk evaluasi agar profit terus meningkat.
